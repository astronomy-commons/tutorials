# %%
from dirac import DataBase

# %%
db = DataBase(conf={"spark.executor.instances" : "32"})
# Out:
# <p><strong>Dashboard: <a href=https://hub.dirac.astro.washington.edu/user/stevenstetzler/proxy/4040/jobs/>https://hub.dirac.astro.washington.edu/user/stevenstetzler/proxy/4040/jobs/</a></strong></p> <p><strong>Status:</strong> Creating SparkSession </p> <p>Setting config: spark.executor.instances=32<p> <p>Setting config: spark.kubernetes.executor.podNamePrefix=pyspark-1567590362-stevenstetzler-spark<p> <p><strong>Status:</strong> Polling Kubernetes cluster</p> <p>Updated at: 2019-09-04 09:46:18.402262</p> <table> <tr> <th>Status</th> <th>Pod Name</th> <th>Message</th> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-1</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-10</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-11</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-12</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-13</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-14</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-15</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-16</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-17</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-18</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-19</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-2</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-20</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-21</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-22</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-23</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-24</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-25</td> <td>Started container</td> </tr> <tr style='overflow-x: scroll;'> <td style='color: green;'><strong>Running</strong></td> <td>pyspark-1567590362-stevenstetzler-spark-exec-26</td> <td>Started container</td> </tr> <tr style='overflow- ...

# %%
catalogs = db.get_catalogs()
gaia = catalogs.load("gaiadr2")

# %%
x, y, z = gaia.histogram2d(gaia.ra, gaia.dec, 1000, 1000)

# %%
from matplotlib import pyplot as plt, rcParams
import matplotlib

# %%
rcParams['figure.figsize'] = [10, 8]
rcParams['figure.dpi'] = 120

# %%
plt.pcolormesh(x, y, z, norm=matplotlib.colors.LogNorm())
plt.xlabel("ra")
plt.ylabel("dec")
plt.colorbar()
plt.show()
